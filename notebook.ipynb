# %%
# Basic Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Matplotlib Plot
x = np.linspace(0, 20, 100)
plt.plot(x, np.sin(x))
plt.show()

# %%
# Bokeh Plot
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
output_notebook()
p = figure(plot_width=400, plot_height=400)
p.circle([1,2,3,4,5], [6,7,2,4,5], size=15, line_color="navy", fill_color="orange", fill_alpha=0.5)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="1bb1f6d9-6f2a-4f60-8424-09d06477f4d0" data-root-id="1003"></div>

# %%
# Progress bar
from tqdm import trange
import time
for i in trange(100):
    time.sleep(0.01)
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 92.52it/s]

# %% [markdown]
# # # Heading
# # ## Sub-heading
# # *bold*,_italic_,`monospace`
# # Horizontal rule
# # ---
# # Bullet List
# # * Apples
# # * Pears
# # Numbered List
# # 1. ???
# # 2. Profit
# #
# # [Link](http://www.microsoft.com)

# %%
# Magics
# %whos
# Out:
# Variable          Type        Data/Info
# ---------------------------------------
# figure            function    <function figure at 0x7fb1c5b06af0>
# i                 int         99
# np                module      <module 'numpy' from '/us<...>lobal/numpy/__init__.py'>
# os                module      <module 'os' from '/usr/l<...>cal/lib/python3.9/os.py'>
# output_notebook   function    <function output_notebook at 0x7fb1c5b111f0>
# p                 Figure      Figure(id='1003', ...)
# pd                module      <module 'pandas' from '/u<...>obal/pandas/__init__.py'>
# plt               module      <module 'matplotlib.pyplo<...>al/matplotlib/pyplot.py'>
# show              function    <function show at 0x7fb1c5b11700>
# sys               module      <module 'sys' (built-in)>
# time              module      <module 'time' (built-in)>
# trange            function    <function trange at 0x7fb1c5a77160>
# x                 ndarray     100: 100 elems, type `float64`, 800 bytes

# %%
# Some extra variable types for the variable explorer
myNparray = np.array([['Bob', 1, 2, 3], ['Alice', 4, 5, 6], ['Gina', 7, 8, 9]])
myDataFrame = pd.DataFrame(myNparray, columns=['name', 'b', 'c', 'd'])
mySeries = myDataFrame['name']
myList = [x ** 2 for x in range(0, 100000)]
myString = 'testing testing testing'

# %%
# Altair (vega)
import altair as alt
from vega_datasets import data

iris = data.iris()

alt.Chart(iris).mark_point().encode(
    x='petalLength',
    y='petalWidth',
    color='species'
)
# Out:
# alt.Chart(...)

# %%
# Plotly
import plotly.graph_objects as go
fig = go.Figure(data=go.Bar(y=[2, 3, 1, 5]))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1817/3725157510.py in <module>
#       2 import plotly.graph_objects as go
#       3 fig = go.Figure(data=go.Bar(y=[2, 3, 1, 5]))
# ----> 4 fig.show()
#
# /usr/local/pip-global/plotly/basedatatypes.py in show(self, *args, **kwargs)
#    3396         import plotly.io as pio
#    3397
# -> 3398         return pio.show(self, *args, **kwargs)
#    3399
#    3400     def to_json(self, *args, **kwargs):
#
# /usr/local/pip-global/plotly/io/_renderers.py in show(fig, renderer, validate, **kwargs)
#     395
#     396         if not nbformat or LooseVersion(nbformat.__version__) < LooseVersion("4.2.0"):
# --> 397             raise ValueError(
#     398                 "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     399             )
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
